# %%
# Simple Quiz Game

questions = [
    {
        "question": "Who is the current president of Nigeria?",
        "choices": ["A. Peter obi", "B. Akpabio", "C. Bola Tinubu", "D. David mark"],
        "answer": "C"
    },
    {
        "question": "What is 2 + 2?",
        "choices": ["A. 3", "B. 4", "C. 5", "D. 6"],
        "answer": "B"
    },
    {
        "question": "Which is the capital of Nigeria?",
        "choices": ["A. Lagos", "B. Ibadan", "C. Abuja", "D. Calabar"],
        "answer": "C"
    }
]

score = 0  # Variable to keep track of the score

for Q in questions:
    print("\n" + Q["question"])
    for choice in Q["choices"]:
        print(choice)

    answer = input("Enter your answer (A, B, C, or D): ").strip().upper()

    if answer == Q["answer"]:
        print("Correct!")
        score += 1
    else:
        print(f"Wrong! The correct answer is {q['answer']}.")

print(f"\nYour final score is {score} out of {len(questions)}.")

if score == len(questions):
    print("Excellent! You got all answers correct!")
elif score > 0:
    print("Good job! Keep practicing.")
else:
    print("Better luck next time!")
# Out:
# Who is the current president of Nigeria?
# A. Peter obi
# B. Akpabio
# C. Bola Tinubu
# D. David mark
# Enter your answer (A, B, C, or D): c
# Correct!
#
# What is 2 + 2?
# A. 3
# B. 4
# C. 5
# D. 6
# Enter your answer (A, B, C, or D): b
# Correct!
#
# Which is the capital of Nigeria?
# A. Lagos
# B. Ibadan
# C. Abuja
# D. Calabar
# Enter your answer (A, B, C, or D): c
# Correct!
#
# Your final score is 3 out of 3.
# Excellent! You got all answers correct!
